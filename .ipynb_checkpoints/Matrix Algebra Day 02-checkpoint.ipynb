# %% [markdown]
# # Parametric Representation of Lines

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('hWhs2cIj7Cw')
#https://www.youtube.com/watch?v=hWhs2cIj7Cw

# %% [markdown]
# R2 : Set of all real number tuples.
#
# 9:00 | L = {X + t V | t E R}
#
# 16:55 | Ploting the line between two points / x,y system of equations
#
# 19:15 | Ploting a line in R3 (three dimensions)
#
# 20:40 | L = { P + t(P-Q) | t E R}
#
# L is a line defined by the paramertric representation of two Vectors, P,Q. Where the line is the sum of V plus the quantity of P minus Q (P-Q) times some real scalar, t. Where t is a member (E) of the real numbers (R).

# %% [markdown]
# ## Plotting a line the R3
#
# x + y + z = k
# This equation is not a line, it is a plane.
#
# The only wat to plot a line or curve is thru a set of parametric equations.
# x = p1 + tq1
# y = p2 + tq2
# z = p3 + tq3
